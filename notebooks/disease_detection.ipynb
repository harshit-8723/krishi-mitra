# %%
# !pip install tensorflow pillow matplotlib
# Out:
# Requirement already satisfied: tensorflow in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (2.15.0)
# Requirement already satisfied: pillow in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (11.1.0)
# Requirement already satisfied: matplotlib in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (3.10.8)
# Requirement already satisfied: tensorflow-intel==2.15.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.8)
# Requirement already satisfied: setuptools in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.10)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.1.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.46.3)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in C:\Users\HP\anaconda3\envs\krishimitra\Lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.2)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# %%
data_dir = "../datasets/crop_diseases"

# %%
img_height = 128
img_width = 128
batch_size = 32

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    seed=42
)

validation_generator = validation_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    seed=42
)

num_classes = train_generator.num_classes
class_names = list(train_generator.class_indices.keys())

print(num_classes)
# Out:
# Found 73380 images belonging to 51 classes.
# Found 18322 images belonging to 51 classes.
# 51

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
epochs = 15

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator
)
# Out:
# Epoch 1/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1846s 804ms/step - accuracy: 0.4873 - loss: 1.6875 - val_accuracy: 0.7001 - val_loss: 0.8315
# Epoch 2/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1101s 480ms/step - accuracy: 0.6596 - loss: 0.9337 - val_accuracy: 0.7139 - val_loss: 0.7238
# Epoch 3/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1215s 529ms/step - accuracy: 0.7060 - loss: 0.7384 - val_accuracy: 0.7523 - val_loss: 0.5504
# Epoch 4/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1162s 506ms/step - accuracy: 0.7266 - loss: 0.6562 - val_accuracy: 0.7563 - val_loss: 0.5570
# Epoch 5/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1190s 518ms/step - accuracy: 0.7393 - loss: 0.6011 - val_accuracy: 0.7753 - val_loss: 0.4961
# Epoch 6/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1053s 459ms/step - accuracy: 0.7498 - loss: 0.5585 - val_accuracy: 0.7932 - val_loss: 0.4191
# Epoch 7/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1077s 469ms/step - accuracy: 0.7561 - loss: 0.5345 - val_accuracy: 0.7769 - val_loss: 0.4700
# Epoch 8/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1105s 482ms/step - accuracy: 0.7622 - loss: 0.5125 - val_accuracy: 0.7664 - val_loss: 0.5070
# Epoch 9/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 966s 421ms/step - accuracy: 0.7675 - loss: 0.4905 - val_accuracy: 0.7637 - val_loss: 0.5589
# Epoch 10/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 960s 418ms/step - accuracy: 0.7691 - loss: 0.4859 - val_accuracy: 0.7809 - val_loss: 0.4492
# Epoch 11/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 1297s 565ms/step - accuracy: 0.7735 - loss: 0.4675 - val_accuracy: 0.7895 - val_loss: 0.4235
# Epoch 12/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 979s 427ms/step - accuracy: 0.7763 - loss: 0.4636 - val_accuracy: 0.7848 - val_loss: 0.5052
# Epoch 13/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 3194s 1s/step - accuracy: 0.7771 - loss: 0.4502 - val_accuracy: 0.7792 - val_loss: 0.4771
# Epoch 14/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 15379s 7s/step - accuracy: 0.7804 - loss: 0.4384 - val_accuracy: 0.7823 - val_loss: 0.4701
# Epoch 15/15
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 9273s 4s/step - accuracy: 0.7832 - loss: 0.4374 - val_accuracy: 0.7954 - val_loss: 0.4247

# %%
model.save("new_plant_disease_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("new_plant_model.keras")

# %%
print(class_names)
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy', 'Tomato_healthy', 'Unknown']
